# %% [markdown]
# # Predicting the property crime rate in states using machine learning
#
# In this notebook, we will use the FBI's UCR (Uniform Crime Reporting) to create a time-series to perform a regression analysis on to see property crime rates in various states and forecast potential property crimes.
#
# ## 1. Problem Definition
# Predict property crime rates by a state-by-state basis.
#
# ## 2. Data
#
# The data has been downloaded by the FBI's UCR crime explorer.
# https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/explorer/crime/crime-trend
#
# ## 3. Evaluation
# To evaluate our time series predictions, we will use multiple metrics:
#
# 1. RMSE (Root Mean Square Error)
#    * Primary metric
#    * Measures average prediction error in actual crime rate units
#    * More weight to large errors
#    * Interpretable: "On average, our predictions are off by X crimes per 100,000 population"
#
# 2. MAPE (Mean Absolute Percentage Error)
#    * Shows error as a percentage
#    * Useful for comparing accuracy across states with different crime rates
#    * Easy to explain: "Our predictions are off by X% on average"
#
# 3. R² Score
#    * Indicates how much of the variance in crime rates our model explains
#    * Useful for model comparison and communication with stakeholders
#
# ## 4. Features

# %% [markdown]
# ### 1. Clean data

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
import pandas as pd
import glob
import os

# def process_state_file(file_path):
#     """
#     Process individual state crime rate files
    
#     Parameters:
#     file_path (str): Path to state CSV file
    
#     Returns:
#     pd.DataFrame: Processed data for one state
#     """
#     # Extract state name from filename
#     state = os.path.basename(file_path).replace('_PropertyCrimeRate.csv', '')
    
#     # Read the CSV
#     df = pd.read_csv(file_path)
    
#     # Melt the dataframe to convert from wide to long format
#     df_melted = pd.melt(df, id_vars=['series'])
#     df_melted['']
    
#     # Convert date strings to datetime
#     df_melted['date'] = pd.to_datetime(df_melted['variable'], format='%m-%Y')
    
#     # Create separate dataframes for each series type
#     crime_rates = df_melted[df_melted['series'] == state].copy()
#     clearance_rates = df_melted[df_melted['series'] == f'{state} Clearances'].copy()
    
#     # Combine the rates
#     final_df = pd.DataFrame({
#         'state': state,
#         'date': crime_rates['date'],
#         'crime_rate': crime_rates['value'],
#         'clearance_rate': clearance_rates['value']
#     })
    
#     return final_df

# def process_state_file(file_path):
#     """
#     Process individual state crime rate files without any cleaning
    
#     Parameters:
#     file_path (str): Path to state CSV file
    
#     Returns:
#     pd.DataFrame: Raw processed data for one state
#     """
#     # Extract state name from filename
#     state = os.path.basename(file_path).replace('_PropertyCrimeRate.csv', '')
    
#     # Read the CSV
#     df = pd.read_csv(file_path)
    
#     # Get the state's crime rate series (first row)
#     state_data = df.iloc[0]
    
#     # Convert to long format
#     data_long = pd.DataFrame({
#         'date': state_data.index[1:],  # Skip 'series' column
#         'crime_rate': state_data.values[1:],  # Skip state name
#         'state': state
#     })
    
#     # Convert dates only
#     data_long['date'] = pd.to_datetime(data_long['date'], format='%m-%Y')
    
#     print(f"Processed {state}")
#     return data_long

def process_state_file(file_path):
    """
    Process individual state crime rate files with proper type conversion
    """
    # Extract state name from filename
    state = os.path.basename(file_path).replace('_PropertyCrimeRate.csv', '')
    
    # Read the CSV
    df = pd.read_csv(file_path)
    
    # Get the state's crime rate series (first row)
    state_data = df.iloc[0]
    
    # Convert to long format with proper types
    data_long = pd.DataFrame({
        'date': pd.to_datetime(state_data.index[1:], format='%m-%Y'),
        'crime_rate': pd.to_numeric(state_data.values[1:], errors='coerce'),  # Convert to float
        'state': state
    })
    
    # Ensure state is string type
    data_long['state'] = data_long['state'].astype(str)
    
    print(f"Processed {state}")
    return data_long

# %%
# def combine_state_files(data_directory):
#     """
#     Process all state files in directory and combine them
    
#     Parameters:
#     data_directory (str): Path to directory containing state CSV files
    
#     Returns:
#     pd.DataFrame: Combined dataset with all states
#     """
#     # Get list of all CSV files
#     files = glob.glob(os.path.join(data_directory, '*_PropertyCrimeRate.csv'))
    
#     # Process each file
#     all_states = []
#     for file in files:
#         try:
#             state_df = process_state_file(file)
#             all_states.append(state_df)
#             print(f"Processed {os.path.basename(file)}")
#         except Exception as e:
#             print(f"Error processing {file}: {str(e)}")
    
#     # Combine all states
#     combined_df = pd.concat(all_states, ignore_index=True)
    
#     # Sort by state and date
#     combined_df = combined_df.sort_values(['state', 'date'])
    
#     return combined_df

# def combine_state_files(data_directory):
#     """
#     Combine all state files into one dataframe
    
#     Parameters:
#     data_directory (str): Path to directory containing state CSV files
    
#     Returns:
#     pd.DataFrame: Combined raw dataset with all states
#     """
#     # Get list of all CSV files
#     files = glob.glob(os.path.join(data_directory, '*_PropertyCrimeRate.csv'))
    
#     # Process each file
#     all_states = []
#     for file in files:
#         state_df = process_state_file(file)
#         all_states.append(state_df)
    
#     # Combine all states
#     combined_df = pd.concat(all_states, ignore_index=True)
    
#     # Sort by state and date
#     combined_df = combined_df.sort_values(['state', 'date'])
    
#     return combined_df

def combine_state_files(data_directory):
    """
    Combine all state files into one dataframe with proper types
    """
    files = glob.glob(os.path.join(data_directory, '*_PropertyCrimeRate.csv'))
    
    all_states = []
    for file in files:
        state_df = process_state_file(file)
        all_states.append(state_df)
    
    combined_df = pd.concat(all_states, ignore_index=True)
    combined_df = combined_df.sort_values(['state', 'date'])
    
    return combined_df

# %%
def validate_combined_data(df):
    """
    Validate the combined dataset
    
    Parameters:
    df (pd.DataFrame): Combined state data
    
    Returns:
    dict: Validation statistics
    """
    stats = {
        'total_states': df['state'].nunique(),
        'date_range': (df['date'].min(), df['date'].max()),
        'missing_values': df.isnull().sum().to_dict(),
        'states_missing_data': []
    }
    
    # Check for states with incomplete time series
    expected_counts = len(df['date'].unique())
    state_counts = df.groupby('state').size()
    missing_data_states = state_counts[state_counts < expected_counts]
    stats['states_missing_data'] = missing_data_states.index.tolist()
    
    return stats

# %%
# Example usage in Jupyter:
data_dir = r'data/StateCrimes'
m_combined_data = combine_state_files(data_dir)

# Look at the raw data
print("\nFirst few rows:")
print(combined_data.head())

# Basic info about the dataset
print("\nDataset Info:")
print(combined_data.info())

# Save raw data
combined_data.to_csv("raw_combined_state_crime_rates.csv", index=False)
# Out:
# Processed Alabama
# Processed Alaska
# Processed Arizona
# Processed Arkansas
# Processed California
# Processed Colorado
# Processed Connecticut
# Processed Delaware
# Processed DistrictOfColumbia
# Processed Florida
# Processed Georgia
# Processed Hawaii
# Processed Idaho
# Processed Illinois
# Processed Indiana
# Processed Iowa
# Processed Kansas
# Processed Kentucky
# Processed Louisiana
# Processed Maine
# Processed Maryland
# Processed Massachusetts
# Processed Michigan
# Processed Minnesota
# Processed Mississippi
# Processed Missouri
# Processed Montana
# Processed Nebraska
# Processed Nevada
# Processed NewHampshire
# Processed NewMexico
# Processed NewYersey
# Processed NewYork
# Processed NorthCarolina
# Processed NorthDakota
# Processed Ohio
# Processed Oklahoma
# Processed Oregon
# Processed Pennsylvania
# Processed RhodeIsland
# Processed SouthCarolina
# Processed SouthDakkota
# Processed Tennessee
# Processed Texas
# Processed US
# Processed Utah
# Processed Vermont
# Processed Virginia
# Processed Washington
# Processed WestVirginia
# Processed Wisconsin
# Processed Wyoming
#
# First few rows:
#         date crime_rate    state
# 0 1985-01-01     296.58  Alabama
# 1 1985-02-01     261.86  Alabama
# 2 1985-03-01     288.37  Alabama
# 3 1985-04-01     265.32  Alabama
# 4 1985-05-01     281.24  Alabama
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24856 entries, 0 to 24855
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        24856 non-null  datetime64[ns]
#  1   crime_rate  24304 non-null  object
#  2   state       24856 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 582.7+ KB
# None

# %%
m_combined_data.isna().sum()
# Out:
# date            0
# crime_rate    552
# state           0
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(m_combined_data['date'][:1000], m_combined_data['crime_rate'][:1000]);

# %%
validate_combined_data(m_combined_data)
# Out:
# {'total_states': 52,
#  'date_range': (Timestamp('1985-01-01 00:00:00'),
#   Timestamp('2024-10-01 00:00:00')),
#  'missing_values': {'date': 0, 'crime_rate': 552, 'state': 0},
#  'states_missing_data': []}

# %%
# Make a copy 
m_combined_data_copy = m_combined_data

# %% [markdown]
# ### Convert strings to categories
# Turn data into numbers by converting them into pandas categories.
